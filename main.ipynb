# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepFake-Detection-UFF/DeepFake-Detection-Breno/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mtcnn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.3 MB/s eta 0:00:00
# ...

# %%
import cv2 as cv
import os
import tensorflow as tf
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

#BGR image
img = cv.imread('/content/drive/MyDrive/mark-zuckerberg-facebook.jpg')

# %%
# convert to RGB
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
from mtcnn.mtcnn import MTCNN

detector = MTCNN()

#detect face
results = detector.detect_faces(img)

# %%
results
# Out:
# [{'box': [614, 129, 377, 527],
#   'confidence': 0.9969291090965271,
#   'keypoints': {'nose': [838, 438],
#    'mouth_right': [904, 526],
#    'right_eye': [898, 328],
#    'left_eye': [724, 337],
#    'mouth_left': [753, 529]}}]

# %%
x,y,w,h = results[0]['box']

img = cv.rectangle(img, (x,y), (x+w, y+h), (0,0,255), 30)
plt.imshow(img)
